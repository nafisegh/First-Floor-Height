# %%
import urllib, os, requests, shutil

import pandas as pd

import glob

import numpy as np

#myloc = 'F:/Backup_Nafiseh_Hard_Drives/BIC_GSV.tar/BIC_GSV/fortworth_test_region/' 
#myloc = 'F:/Backup_Nafiseh_Hard_Drives/BIC_GSV.tar/BIC_GSV/vancouver_test_region/'
myloc = 'D:/Nafiseh/Building_Footprint_Clip/'
#replace with your own location

#key = "&key=" + "" #got banned after ~100 requests with no key

def GetStreet(Add,building_id, clas,SaveLoc):
    
  base = "https://maps.googleapis.com/maps/api/streetview?"
  #MyUrl = base + urllib.parse.quote_plus(Add) + key #added url encoding
    
  #print(Add)
  try:  

      #fi = Add+ ".jpg"
      fi = str(building_id) + ".jpg"  

      #key = "AIzaSyAhcb5ZootD29kErmSzmWDaKqoMGtDd5lc"  
      key = "AIzaSyDGOySIdFF6_scE3pTGerUDkLiqWx4bTmQ"  

      #urllib.request.urlretrieve(MyUrl, os.path.join(SaveLoc,fi))
      headers={'USER-AGENT': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/105.0.0.0 Safari/537.36 Edg/105.0.1343.53'}

      #fov=[90,45,22.5]
      fov=[45] 

      #heading=[0,90,180,270]

      heading=[0] 


      for f in fov:

        for h in heading:

          #folder='fov_'+str(f)+'/'+'heading_'+str(h) 
          #folder='TRCA_GTA_Most_Records/test2'
          #folder='Toronto/Remix/FOV_{}_heading_{}'.format(f,h)+'/'+str(clas)
          #folder='Toronto/My_Classes_web_and_google_dataset_2/'+str(clas) 
          #folder = 'fortworth_test_GSV_with_address/' +str(clas)
          #folder = 'vancouver_test_GSV_with_address/'  +str(clas) 
          folder = 'Data_GSV_2/' +str(clas)
          #folder='Hampton_Roads_IMG' 


          #pic_params={'key': key , 'location': Add , 'size': '512x512', 'heading' : str(h), 'fov' : str(f)} 

          pic_params={'key': key , 'location': Add , 'size': '512x512'}  

          direc=SaveLoc+folder 
          #print(direc)  

          if os.path.exists(direc):

             r=requests.get(base, params=pic_params, headers=headers)
               

          else:  


            os.makedirs(direc)


            r=requests.get(base, params=pic_params, headers=headers)
            


          #print(r.status_code)  



          with open(direc+'/'+fi,'wb') as outfile:

               outfile.write(r.content) 


          r.close()

          outfile.close()  
            
  except Exception as error:

        print(Add)
        #raise(error)
        pass


  #for keys,value in r.headers.items():
        
      #print(f"{keys}: {value}")  


#files=glob.glob(r'D:\Building_Type_GSV\Mixed\FOV_90_heading_0\*.jpg')

#samples=[os.path.basename(f).split('.jpg')[0] for f in files]
#samples=pd.read_excel('C:/Users/asus/Desktop/FFH.xlsx',header=45)


#samples_florida_state=pd.read_excel('C:/Users/asus/Desktop/FFH_project/Elevation Certificate_City_Upload.xlsx')
#samples_hampton_roads=pd.read_csv('D:/GSV/Hampton_Roads_Elevation_Certificates_(NAVD_88).csv')
#samples_toronto_building_type=pd.read_csv('D:/Building_Type_GSV/Mixed_Residential_Commercial_Addresses_Toronto.csv')
#samples_toronto_building_type = pd.read_csv('D:/Nafiseh/building_type/loopnet_web_scraping - editted.csv')
#samples_toronto_building_type = pd.read_csv('D:/Nafiseh/building_type/remix_geocoded_buildings.csv')
#samples_toronto_building_type = pd.read_csv('D:/Nafiseh/building_type/Union_building_footprints_remax_regeocoded.csv')
#samples_fortworth = pd.read_csv(r'F:\Backup_Nafiseh_Hard_Drives\BIC_GSV.tar\BIC_GSV\fortworth_test_region\building_footprint_fortworth_2.csv')
#samples_vancouver = pd.read_csv(r'D:\Nafiseh\building_type\LiDAR Data\Vancouver\Building_Footprint\building_footprint_reverse_geocode_with_land_use.csv')
samples_gta = pd.read_csv('D:/Nafiseh/Building_Footprint_Clip/Addresses.csv', usecols = ['Build_ID','REV_Match_addr','landuse'])
#samples_GTA=pd.read_excel('D:/GSV/BuildingInventory_wDamages FirstFloorHeight only - Copy.xlsx')
#samples_GTA=pd.read_csv('D:/GSV/BuildingInventoryGeo-Copy.csv')
#samples_GTA=pd.read_csv('D:/GSV/TRCA_GTA_Most_Records_wrong_Geo_corrected.csv')
#samples=pd.read_csv('D:/Building_Type_GSV/loop_net_mixed_Residential_Commercial_Addresses.csv')

#Tests=samples_toronto_building_type.iloc[[3,4,5,7,9],1]

#Tests = samples_toronto_building_type['joined_A_1']+','+samples_toronto_building_type['joined_Cit']+','+samples_toronto_building_type['joined_Sta']

#Tests = samples_fortworth['ADDRESS']+','+'Fortworth'
#Tests = samples_vancouver['REV_Match_']
Tests = samples_gta['REV_Match_addr']
#class_ = samples_toronto_building_type['Class']

#class_ = samples_toronto_building_type['joined_typ']

####################################3

build_id = samples_gta['Build_ID']
#class_ = samples_fortworth['landuse']
#class_ =samples_vancouver['landuse']
class_ = samples_gta['landuse']
        
#Tests=samples_GTA['Address']

#Tests=glob.glob('D:/GSV/TRCA_GTA_Most_Records/test2/*.jpg')

#Testss=[os.path.basename(i).replace('-',' ').split('.jpg',1)[0] for i in Tests] 

#Tests=samples_hampton_roads['ADDRESS']


#Tests=samples_GTA.iloc[:,0]
#Tests=np.copy(samples)
#Tests=samples.iloc[:,1]

for i,k,j in zip(Tests,build_id, class_):

    
    GetStreet(i,k,j,SaveLoc=myloc)

# %%
import pandas as pd

samples_toronto_building_type=pd.read_csv('D:/Building_Type_GSV/Mixed_Residential_Commercial_Addresses.csv')


Tests=samples_toronto_building_type.iloc[1,1]
        
    
print(Tests)

# %%
import scipy.io

b_inst = scipy.io.loadmat(r'F:\Backup_Nafiseh_Hard_Drives\BIC_GSV.tar\BIC_GSV\vancouver_test_region\building_instance_lat_lon.mat')

print(b_inst.shape)
